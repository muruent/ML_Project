# %%
#importing libraries
import pandas as pd # for data processing
import matplotlib.pyplot as plt # plotting
import numpy as np # simple linear algebra

from scipy import stats
from scipy.stats import norm
from scipy.stats import skew
from scipy.stats.stats import pearsonr
from sklearn import decomposition
# %matplotlib inline
from scipy.stats import norm
import collections
import warnings
import xgboost as xgb
import lightgbm as lgb
import seaborn as sns; sns.set(style="ticks", color_codes=True)
from collections import Counter

color = sns.color_palette()
sns.set_style('darkgrid')
# %config InlineBackend.figure_format = 'png' #sns.set(style='white', context='notebook', palette='deep')
def ignore_warn(*args, **kwargs):
    pass
warnings.warn = ignore_warn
warnings.filterwarnings('ignore')
pd.set_option('display.float_format', lambda x: '{:.3f}'.format(x)) #Limiting floats output to 3 decimal points

# %%
df_train = pd.read_csv('train.csv')
df_test = pd.read_csv('test.csv')

# %%
df_train.shape #checking the numbe rof columns and rows
# Out:
# (1460, 81)

# %%
df_train.columns.values
# Out:
# array(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
#        'BldgType', 'HouseStyle', 'OverallQual', 'OverallCond',
#        'YearBuilt', 'YearRemodAdd', 'RoofStyle', 'RoofMatl',
#        'Exterior1st', 'Exterior2nd', 'MasVnrType', 'MasVnrArea',
#        'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond',
#        'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating', 'HeatingQC',
#        'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu',
#        'GarageType', 'GarageYrBlt', 'GarageFinish', 'GarageCars',
# ...

# %%
#visualizing df
df_train.head(5)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL       65.000     8450   Pave   NaN      Reg
# 1   2          20       RL       80.000     9600   Pave   NaN      Reg
# 2   3          60       RL       68.000    11250   Pave   NaN      IR1
# 3   4          70       RL       60.000     9550   Pave   NaN      IR1
# 4   5          60       RL       84.000    14260   Pave   NaN      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 3         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 4         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
#checking the numbe rof columns and rows. Note that the test data missing sale price that you have to predict
df_test.shape
df_test.head(5)
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH       80.000    11622   Pave   NaN      Reg
# 1  1462          20       RL       81.000    14267   Pave   NaN      IR1
# 2  1463          60       RL       74.000    13830   Pave   NaN      IR1
# 3  1464          60       RL       78.000     9978   Pave   NaN      IR1
# 4  1465         120       RL       43.000     5005   Pave   NaN      IR1
#
#   LandContour Utilities      ...       ScreenPorch PoolArea PoolQC  Fence  \
# 0         Lvl    AllPub      ...               120        0    NaN  MnPrv
# 1         Lvl    AllPub      ...                 0        0    NaN    NaN
# 2         Lvl    AllPub      ...                 0        0    NaN  MnPrv
# 3         Lvl    AllPub      ...                 0        0    NaN    NaN
# 4         HLS    AllPub      ...               144        0    NaN    NaN
#
#   MiscFeature MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
#check the column or variable names
df_train.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
print("The train data size before dropping Id feature is : {} ".format(df_train.shape))
print("The test data size before dropping Id feature is : {} ".format(df_test.shape))

#Save the 'Id' column
train_ID = df_train['Id']
test_ID = df_test['Id']

#Now drop the  'Id' colum since it's unnecessary for  the prediction process.
df_train.drop("Id", axis = 1, inplace = True)
df_test.drop("Id", axis = 1, inplace = True)

#check again the data size after dropping the 'Id' variable
print("\nThe train data size after dropping Id feature is : {} ".format(df_train.shape)) 
print("The test data size after dropping Id feature is : {} ".format(df_test.shape))
# Out:
# The train data size before dropping Id feature is : (1460, 81)
# The test data size before dropping Id feature is : (1459, 80)
#
# The train data size after dropping Id feature is : (1460, 80)
# The test data size after dropping Id feature is : (1459, 79)

# %%
#Deleting outliers
df_train = df_train.drop(df_train[(df_train['GrLivArea']>4000) & (df_train['SalePrice']<300000)].index)

# %%
# plotting after removing outliers

# %%
fig, ax = plt.subplots()
ax.scatter(x = df_train['GrLivArea'], y = df_train['SalePrice'], color = 'green')
plt.ylabel('Sales Price', fontsize=15)
plt.xlabel('Living Area', fontsize=15)
plt.show()

# %%
df_train['SalePrice'].describe()
# Out:
# count     1458.000
# mean    180932.919
# std      79495.055
# min      34900.000
# 25%     129925.000
# 50%     163000.000
# 75%     214000.000
# max     755000.000
# Name: SalePrice, dtype: float64

# %%
sns.distplot(df_train['SalePrice'], fit=norm);

# printing mean and stdv of salesprice
(mu, sigma) = norm.fit(df_train['SalePrice'])
print( '\n mu = {:.2f} and sigma = {:.2f}\n'.format(mu, sigma))

#Now plot the distribution
plt.legend(['Normal dist. ($\mu=$ {:.2f} and $\sigma=$ {:.2f} )'.format(mu, sigma)],
            loc='best')
plt.ylabel('Frequency', fontsize=15)
plt.title('Visualizing Sales Price Distribution', fontsize=15)

#Get also the QQ-plot
fig = plt.figure()
res = stats.probplot(df_train['SalePrice'], plot=plt)
plt.show()

print("Skewness: %f" % df_train['SalePrice'].skew())
print("Kurtosis: %f" % df_train['SalePrice'].kurt())
# Out:
#  mu = 180932.92 and sigma = 79467.79
# Skewness: 1.881296
# Kurtosis: 6.523067

# %%
# it doesn't look normal so, using log transformation for saleprice
df_train["SalePrice"] = np.log1p(df_train["SalePrice"])

# %%
sns.distplot(df_train['SalePrice'], fit=norm);

# printing mean and stdv of salesprice
(mu, sigma) = norm.fit(df_train['SalePrice'])
print( '\n mu = {:.2f} and sigma = {:.2f}\n'.format(mu, sigma))

#Now plot the distribution
plt.legend(['Normal dist. ($\mu=$ {:.2f} and $\sigma=$ {:.2f} )'.format(mu, sigma)],
            loc='best')
plt.ylabel('Frequency', fontsize=15)
plt.title('Visualizing Sales Price Distribution', fontsize=15)

#Get also the QQ-plot
fig = plt.figure()
res = stats.probplot(df_train['SalePrice'], plot=plt)
plt.show()

print("Skewness: %f" % df_train['SalePrice'].skew())
print("Kurtosis: %f" % df_train['SalePrice'].kurt())
# Out:
#  mu = 12.02 and sigma = 0.40
# Skewness: 0.121580
# Kurtosis: 0.804751

# %%
#looking into all categorical values
df_train.select_dtypes(include=['object']).columns
# Out:
# Index(['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities',
#        'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
#        'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
#        'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
#        'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature',
#        'SaleType', 'SaleCondition'],
#       dtype='object')

# %%
# loking inot numerical predictor variables
df_train.select_dtypes(include=['int64','float64']).columns
# Out:
# Index(['MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual', 'OverallCond',
#        'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2',
#        'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces',
#        'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal',
#        'MoSold', 'YrSold', 'SalePrice'],
#       dtype='object')

# %%
cat = len(df_train.select_dtypes(include=['object']).columns)
num = len(df_train.select_dtypes(include=['int64','float64']).columns)
print('Total Features: ', cat, 'categorical', '+',
      num, 'numerical', '=', cat+num, 'features')
# Out:
# Total Features:  43 categorical + 37 numerical = 80 features

# %%
#Examining influence of different predictor variables

# %%
#correlation matrix
correlation_matrix = df_train.corr()
f, ax = plt.subplots(figsize=(12, 8))
sns.heatmap(correlation_matrix, vmax=.8, square=True,cmap="YlGnBu")

# %%
k = 10 #number of variables for heatmap
corels = correlation_matrix.nlargest(k, 'SalePrice')['SalePrice'].index
cm = np.corrcoef(df_train[corels].values.T)
sns.set(font_scale=1.25)
heatmap = sns.heatmap(cm, cbar=True, annot=True, square=True, fmt='.2f', annot_kws={'size': 10}, yticklabels=corels.values, xticklabels=corels.values,cmap="Greens")
plt.show()

# %%
# indentifying varibales with high correlation

# %%
High_corl = pd.DataFrame(corels)
High_corl.columns = ['Features with high correlations']
High_corl
# Out:
#   Features with high correlations
# 0                       SalePrice
# 1                     OverallQual
# 2                       GrLivArea
# 3                      GarageCars
# 4                      GarageArea
# 5                     TotalBsmtSF
# 6                        1stFlrSF
# 7                        FullBath
# 8                       YearBuilt
# 9                    YearRemodAdd

# %%
#scatterplot
sns.set()
corls = ['SalePrice', 'OverallQual', 'GrLivArea','GarageCars', 'TotalBsmtSF', 'FullBath', 'YearBuilt']
sns.pairplot(df_train[corls], size = 2.0, kind="reg") 
plt.show();

#, hue ='SalePrice', palette="husl"

# %%
# Might be useful to plot saleprice with different highly-correlating variables  but such analysis will be more useful after cleaning, imputation, and feature engineering

# %%
#Combining dataset before feature engineering

# %%
# Combining Datasets. Remember, we are dropping saleprice column
ntrain = df_train.shape[0]
ntest = df_test.shape[0]
y_train = df_train['SalePrice']
combined_data = pd.concat((df_train, df_test)).reset_index(drop=True)
combined_data.drop(['SalePrice'], axis=1, inplace=True)
print("Training data size is : {}".format(df_train.shape))
print("Testing data size is : {}".format(df_test.shape))
print("Combined dataset size is : {}".format(combined_data.shape))
# Out:
# Training data size is : (1458, 80)
# Testing data size is : (1459, 79)
# Combined dataset size is : (2917, 79)

# %%
#Investigating missing values
combined_data_na = (combined_data.isnull().sum() / len(combined_data)) * 100
combined_data_na = combined_data_na.drop(combined_data_na[combined_data_na == 0].index).sort_values(ascending=False)[:30]
missing_data = pd.DataFrame({'Missing Ratio' :combined_data_na})
missing_data
# Out:
#               Missing Ratio
# PoolQC               99.691
# MiscFeature          96.400
# Alley                93.212
# Fence                80.425
# FireplaceQu          48.680
# LotFrontage          16.661
# GarageQual            5.451
# GarageCond            5.451
# GarageFinish          5.451
# GarageYrBlt           5.451
# GarageType            5.382
# BsmtExposure          2.811
# BsmtCond              2.811
# BsmtQual              2.777
# BsmtFinType2          2.743
# BsmtFinType1          2.708
# MasVnrType            0.823
# MasVnrArea            0.788
# MSZoning              0.137
# BsmtFullBath          0.069
# BsmtHalfBath          0.069
# Utilities             0.069
# Functional            0.069
# Electrical            0.034
# BsmtUnfSF             0.034
# Exterior1st           0.034
# Exterior2nd           0.034
# TotalBsmtSF           0.034
# GarageArea            0.034
# GarageCars            0.034

# %%
f, ax = plt.subplots(figsize=(15, 12))
plt.xticks(rotation='90')
sns.barplot(x=combined_data_na.index, y=combined_data_na, palette="deep")
plt.xlabel('Predictor variables', fontsize=15)
plt.ylabel('Percent of missing values', fontsize=15)
plt.title('Percent missing data by variables', fontsize=15)
# Out:
# Text(0.5,1,'Percent missing data by variables')

# %%
#Handling missing (NA) values

# %%
#looking into original description
#https://ww2.amstat.org/publications/jse/v19n3/Decock/DataDocumentation.txt

# %%
#NA means "no alley access", replacing with None
combined_data["Alley"] = combined_data["Alley"].fillna("None")
#NA means "no fireplace", replacing with None
combined_data["FireplaceQu"] = combined_data["FireplaceQu"].fillna("None")
#replacing with most common
combined_data['SaleType'] = combined_data['SaleType'].fillna(combined_data['SaleType'].mode()[0])
combined_data["PoolQC"] = combined_data["PoolQC"].fillna("None")
combined_data["MiscFeature"] = combined_data["MiscFeature"].fillna("None")
combined_data["Alley"] = combined_data["Alley"].fillna("None")
combined_data["Fence"] = combined_data["Fence"].fillna("None")
combined_data["FireplaceQu"] = combined_data["FireplaceQu"].fillna("None")

# %%
#filling front lawn area with median
combined_data["LotFrontage"] = combined_data.groupby("Neighborhood")["LotFrontage"].transform(
    lambda x: x.fillna(x.median()))
#replacing with None
for col in ('GarageType', 'GarageFinish', 'GarageQual', 'GarageCond'):
    combined_data[col] = combined_data[col].fillna('None')
    #Replacing missing numerical data with 0 
for col in ('BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF','TotalBsmtSF', 'BsmtFullBath', 'BsmtHalfBath'):
    combined_data[col] = combined_data[col].fillna(0)
    # these are categorical features related to  basement, hence filling with None.
for col in ('BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2'):
    combined_data[col] = combined_data[col].fillna('None')
for col in ('GarageYrBlt', 'GarageArea', 'GarageCars'):
    combined_data[col] = combined_data[col].fillna(0)

# %%
#NA means no filling with none for type and 0 for area.
combined_data["MasVnrType"] = combined_data["MasVnrType"].fillna("None")
combined_data["MasVnrArea"] = combined_data["MasVnrArea"].fillna(0)

# %%
#MS Zoning (Nominal): Identifies the general zoning classification of the sale. replacing NA with most common value'RL'
counter=collections.Counter(combined_data['MSZoning'])
print(counter.most_common())
combined_data['MSZoning'] = combined_data['MSZoning'].fillna(combined_data['MSZoning'].mode()[0])
# Out:
# [('RL', 2263), ('RM', 460), ('FV', 139), ('RH', 26), ('C (all)', 25), (nan, 4)]

# %%
# all records are "AllPub", except for one "NoSeWa" and 2 NA . As most of the homes had all utitlies, droping this column
    #AllPub	All public Utilities (E,G,W,& S)
    #NoSewr	Electricity, Gas, and Water (Septic Tank)
    #NoSeWa	Electricity and Gas Only
     #ELO	Electricity only_)

# %%
counter=collections.Counter(combined_data['Utilities'])
print(counter.most_common())
# Out:
# [('AllPub', 2914), (nan, 2), ('NoSeWa', 1)]

# %%
#dropping 'Fence', 'MiscFeature', 'GarageYrBlt

# %%
combined_data = combined_data.drop(['Fence', 'MiscFeature', 'GarageYrBlt', 'PoolQC','Utilities'], axis=1)

# %%
combined_data['Electrical'] = combined_data['Electrical'].fillna(combined_data['Electrical'].mode()[0])
#KitchenQual (Ordinal): Kitchen quality - replacing with most common 'TA'- TA	Typical/Average
combined_data['KitchenQual'] = combined_data['KitchenQual'].fillna(combined_data['KitchenQual'].mode()[0])
#replacing with common string 
combined_data['Exterior1st'] = combined_data['Exterior1st'].fillna(combined_data['Exterior1st'].mode()[0])
combined_data['Exterior2nd'] = combined_data['Exterior2nd'].fillna(combined_data['Exterior2nd'].mode()[0])
#MSSubClass : MS SubClass (Nominal): Identifies the type of dwelling involved in the sale.
#Na most likely means no building, replacing missing values with None
combined_data['MSSubClass'] = combined_data['MSSubClass'].fillna("None")
combined_data.Functional.value_counts().sort_index()
combined_data['Functional'] = combined_data['Functional'].fillna(combined_data['Functional'].mode()[0])

# %%
combined_data['MSSubClass'] = combined_data['MSSubClass'].fillna("None")
combined_data.Functional.value_counts().sort_index()
combined_data['Functional'] = combined_data['Functional'].fillna(combined_data['Functional'].mode()[0])

# %%
#Check remaining missing values if any

# %%
# Converting numericals which are not really numericals - 'MSSubClass', 'OverallCond'
combined_data['MSSubClass'] = combined_data['MSSubClass'].apply(str)
#combined_data['OverallCond'] = combined_data['OverallCond'].astype(str)

# %%
#checkig missing values again

# %%
#Investigating missing values
combined_data_na = (combined_data.isnull().sum() / len(combined_data)) * 100
combined_data_na = combined_data_na.drop(combined_data_na[combined_data_na == 0].index).sort_values(ascending=False)[:30]
missing_data = pd.DataFrame({'Missing Ratio' :combined_data_na})
missing_data
# Out:
# Empty DataFrame
# Columns: [Missing Ratio]
# Index: []

# %%
combined_data.GarageFinish.value_counts()
# Out:
# Unf     1230
# RFn      811
# Fin      717
# None     159
# Name: GarageFinish, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

ordinals = ['LotShape','LandSlope','OverallQual','OverallCond','ExterQual','ExterCond','BsmtQual',
           'BsmtCond','BsmtExposure','BsmtFinType1','BsmtFinType2','HeatingQC','Electrical','KitchenQual',
            'Functional','FireplaceQu','GarageFinish','GarageQual','GarageCond','PavedDrive']

for ordinal in ordinals:
    le = LabelEncoder()
    le.fit(combined_data[ordinal].astype(str))
    combined_data[ordinal] = le.transform(combined_data[ordinal].astype(str))
    
print('Shape combined_data: {}'.format(combined_data.shape))
# Out:
# Shape combined_data: (2917, 74)

# %%
#Generating new features which might make more sense

# %%
combined_data['OutdoorSF'] = combined_data['OpenPorchSF'] + combined_data['EnclosedPorch'] + combined_data['3SsnPorch'] + combined_data['ScreenPorch'] + combined_data['WoodDeckSF'] 
combined_data['TotalHalfbath'] = combined_data['BsmtHalfBath'] + combined_data['HalfBath']
combined_data['Totalfullbath'] = combined_data['BsmtFullBath'] + combined_data['FullBath']
combined_data['TotalSF'] = combined_data['TotalBsmtSF'] + combined_data['1stFlrSF'] + combined_data['2ndFlrSF']

# %%
# checking skewed numeric features

# %%
numericals = combined_data.dtypes[combined_data.dtypes != 'object'].index
# Check the skew of all numerical features
skewed_features = combined_data[numericals].apply(lambda x: skew(x.dropna())).sort_values(ascending=False)
print("\nSkewness in numerical features: \n")
skewness = pd.DataFrame({'skewness' :skewed_features})
skewness.head(25)
# Out:
# Skewness in numerical features:
#                skewness
# MiscVal          21.940
# PoolArea         17.689
# LotArea          13.109
# LowQualFinSF     12.085
# 3SsnPorch        11.372
# LandSlope         4.973
# KitchenAbvGr      4.301
# BsmtFinSF2        4.145
# EnclosedPorch     4.002
# ScreenPorch       3.945
# BsmtHalfBath      3.930
# MasVnrArea        2.622
# OpenPorchSF       2.529
# WoodDeckSF        1.845
# OutdoorSF         1.380
# 1stFlrSF          1.257
# LotFrontage       1.103
# GrLivArea         1.069
# TotalSF           1.009
# BsmtFinSF1        0.981
# BsmtUnfSF         0.920
# 2ndFlrSF          0.862
# TotalHalfbath     0.801
# TotRmsAbvGrd      0.749
# Fireplaces        0.725

# %%
# # Inspired by Alexandru Papiu's script : https://www.kaggle.com/apapiu/house-prices-advanced-regression-techniques/regularized-linear-models
skewness = skewness[abs(skewness) > 0.50]
print("There are {} skewed numerical features that have to be box-cox transformed".format(skewness.shape[0]))
from scipy.special import boxcox1p
skewed_features = skewness.index
lam = 0.15 # lam zero will give simple log transformation
for features in skewed_features:
    combined_data[features] = boxcox1p(combined_data[features], lam)
# Out:
# There are 56 skewed numerical features that have to be box-cox transformed

# %%
#Dummification of nominal categorical features 
combined_data = pd.get_dummies(combined_data)
print(combined_data.shape)
# Out:
# (2917, 230)

# %%
#checking combined_data.columns.values

# %%
train_data = combined_data[:ntrain]
test_data = combined_data[ntrain:]

# %%
#to check the column names
#test_data.columns.values

# %%
print("train_data_shape:{}, test_data_shape:{}".format(train_data.shape,test_data.shape))
# Out:
# train_data_shape:(1458, 230), test_data_shape:(1459, 230)

# %%
# Import libraries

from sklearn.model_selection import GridSearchCV,learning_curve, cross_val_score, KFold,train_test_split
from sklearn.preprocessing import Normalizer, StandardScaler, RobustScaler
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.metrics import accuracy_score, mean_squared_error

from sklearn.linear_model import LinearRegression, LassoCV, ElasticNetCV, Lasso, ElasticNet, BayesianRidge, LassoLarsIC
from sklearn.kernel_ridge import KernelRidge
from mlxtend.regressor import StackingRegressor
from sklearn.pipeline import make_pipeline
from sklearn.base import BaseEstimator, TransformerMixin, RegressorMixin, clone

import xgboost as xgb
from xgboost import XGBRegressor
import lightgbm as lgb

# %%
#Feature scaling

# %%
scaler = StandardScaler()
scaler.fit(train_data)
train_data = scaler.transform(train_data)
train_data = pd.DataFrame(train_data)

test_data = scaler.transform(test_data)
test_data = pd.DataFrame(test_data)

# %%
#checking data after scaling
np.mean(train_data).head(5)
np.std(train_data).head(5)
# Out:
# 0   1.000
# 1   1.000
# 2   1.000
# 3   1.000
# 4   1.000
# dtype: float64

# %%
y_train.head()
# Out:
# 0   12.248
# 1   12.109
# 2   12.317
# 3   11.849
# 4   12.429
# Name: SalePrice, dtype: float64

# %%
#defining cross-validation

# %%
n_folds = 5
def rmsle_cv(model):
    kf = KFold(n_folds, shuffle=True, random_state=42).get_n_splits(train_data)
    rmse= np.sqrt(-cross_val_score(model, train_data, y_train, scoring="neg_mean_squared_error", cv = kf))
    return(rmse)

# %%
#LASSO Regression :
# sensitive to outliers, hence, using the sklearn's Robustscaler() method on pipeline

# %%
lasso_model = make_pipeline(RobustScaler(), Lasso(alpha =0.0005, random_state=1))
score = rmsle_cv(lasso_model)
print("\nLasso score: {:.4f} ({:.4f})\n".format(score.mean(), score.std()))

lasso_model.fit(train_data,y_train)
# get predictions
predictions = np.exp(lasso_model.predict(test_data))
predictions

# save predictions in Kaggle-friendly format
solutions = pd.DataFrame(data = {'Id':test_ID,'SalePrice':predictions})
solutions.to_csv('lasso_model_predict.csv',index=False)
# Out:
# Lasso score: 0.1214 (0.0071)

# %%
# Plot important coefficients
coefs = pd.Series(lasso_model.named_steps['lasso'].coef_, index = combined_data.columns)
print("Lasso selected " + str(sum(coefs != 0)) + " features and eliminated the other " +  \
      str(sum(coefs == 0)) + " features")
imp_coefs = pd.concat([coefs.sort_values().head(10),
                     coefs.sort_values().tail(10)])
imp_coefs.plot(kind = "barh")
plt.title("Coefficients in the Lasso Model", fontsize = 15)
plt.xlabel('Coefficients',fontsize=15)
plt.ylabel('Features',fontsize=14)
#plt.tick_params(axis='both',labelsize=14)
plt.show()
# Out:
# Lasso selected 178 features and eliminated the other 52 features

# %%
#lasso_model.named_steps['lasso'].coef_

# %%
#Elastic Net Regression, using the sklearn's Robustscaler() method on pipeline

# %%
ENet_model = make_pipeline(RobustScaler(), ElasticNet(alpha=0.0005, l1_ratio=.9, random_state=3))
score = rmsle_cv(ENet_model)
print("ElasticNet score: {:.4f} ({:.4f})\n".format(score.mean(), score.std()))


ENet_model.fit(train_data, y_train)
# get predictions
predictions = np.exp(ENet_model.predict(test_data))
predictions

# save predictions in Kaggle-friendly format
solutions = pd.DataFrame(data = {'Id':test_ID,'SalePrice':predictions})
solutions.to_csv('ENet_model_predict.csv',index=False)
# Out:
# ElasticNet score: 0.1218 (0.0070)

# %%
ENet_model

# %%
# Plot important coefficients
coefs = pd.Series(ENet_model.named_steps['elasticnet'].coef_, index = combined_data.columns)
print("ENet selected " + str(sum(coefs != 0)) + " features and eliminated the other " +  \
      str(sum(coefs == 0)) + " features")
imp_coefs = pd.concat([coefs.sort_values().head(10),
                     coefs.sort_values().tail(10)])
imp_coefs.plot(kind = "barh")
plt.title("Coefficients in the ENet Model")
plt.show()
# Out:
# ENet selected 179 features and eliminated the other 51 features

# %%
#Kernel Ridge Regression :
KRR_model = KernelRidge(alpha=0.6, kernel='polynomial', degree=2, coef0=2.5)
score = rmsle_cv(KRR_model)
print("Kernel Ridge score: {:.4f} ({:.4f})\n".format(score.mean(), score.std()))

KRR_model.fit(train_data,y_train)
# get predictions
predictions = np.exp(KRR_model.predict(test_data))
predictions

# save predictions in Kaggle-friendly format
solutions = pd.DataFrame(data = {'Id':test_ID,'SalePrice':predictions})
solutions.to_csv('KRR_model_predict.csv',index=False)
# Out:
# Kernel Ridge score: 0.1193 (0.0062)

# %%
#KRR_model.dual_coef_

# %%
#Random Forest

# %%
kfold = KFold(n_splits=20, random_state= 0, shuffle = True)

# %%
RFC = RandomForestRegressor(random_state = 1)

rf_param_grid = {"max_depth": [None],
              "max_features": ['sqrt', 88],
              "min_samples_leaf": [1,2],
              "n_estimators" :[570]
                }
gsRFC = GridSearchCV(RFC,param_grid = rf_param_grid, cv = kfold, scoring = "neg_mean_squared_error", n_jobs = -1, verbose = 1)
gsRFC.fit(train_data,y_train)
RFC_best = gsRFC.best_estimator_

print(gsRFC.best_params_)
print("RandomForest mean score:", rmsle_cv(RFC_best).mean())
print("RandomForest std:", rmsle_cv(RFC_best).std())
# Out:
# Fitting 20 folds for each of 4 candidates, totalling 80 fits
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done  80 out of  80 | elapsed:  3.3min finished
# {'max_depth': None, 'max_features': 88, 'min_samples_leaf': 2, 'n_estimators': 570}
# RandomForest mean score: 0.13217510001328314
# RandomForest std: 0.005982609992327099

# %%
#checking RFC_best.feature_importances_

# %%
RFC_best.feature_importances_
Feature_importances = pd.Series(RFC_best.feature_importances_, index = combined_data.columns)
print("RFCpicked " + str(sum(Feature_importances != 0)) + " features and eliminated the other " +  \
      str(sum(Feature_importances == 0)) + " features")
Important_Features = pd.concat([Feature_importances.sort_values().head(10),
                     Feature_importances.sort_values().tail(10)])
Important_Features.plot(kind = "barh")
plt.title("Important Features in the RFC Model")
plt.show()

# looks at each feature, looks at reduction at each cut off

# %%
XGB = XGBRegressor()
xg_param_grid = {
              'n_estimators' :[870],
              'learning_rate': [0.04],
              
              'max_depth': [3],
              'min_child_weight':[0.2],
              
              'gamma': [0],
                
              'subsample':[0.8],
              'colsample_bytree':[0.7]
              }
gsXGB = GridSearchCV(XGB,param_grid = xg_param_grid, cv=kfold, scoring="neg_mean_squared_error", n_jobs= -1, verbose = 1)
gsXGB.fit(train_data,y_train)
XGB_best = gsXGB.best_estimator_
print(gsXGB.best_params_)

print("XG Boost mean score:", rmsle_cv(XGB_best).mean())
print("XG Boost std:", rmsle_cv(XGB_best).std())

# %%
XGB_best.

# %%
Feature_importances = pd.Series(XGB_best.feature_importances_, index = combined_data.columns)
print("XGB_picked " + str(sum(Feature_importances != 0)) + " features and eliminated the other " +  \
      str(sum(Feature_importances == 0)) + " features")
Important_Features = pd.concat([Feature_importances.sort_values().head(10),
                     Feature_importances.sort_values().tail(10)])
Important_Features.plot(kind = "barh")
plt.title("Important Features in the XGB Model")
plt.show()
plt.savefig('XGB.JPEG', format='eps', dpi=1000, bbox_inches='tight')

# %%
# get predictions for 
predictions = np.exp(lgb_model.predict(test_data))
predictions
# save predictions in Kaggle-friendly format
solutions = pd.DataFrame(data = {'Id':test_ID,'SalePrice':predictions})
solutions.to_csv('lgb_model_predict.csv',index=False)

# %%
lgb_model = lgb.LGBMRegressor(objective='regression',num_leaves=5,
                              learning_rate=0.05, n_estimators=720,
                              max_bin = 55, bagging_fraction = 0.8,
                              bagging_freq = 5, feature_fraction = 0.2319,
                              feature_fraction_seed=9, bagging_seed=9,
                              min_data_in_leaf =6, min_sum_hessian_in_leaf = 11)

score = rmsle_cv(lgb_model)
lgb_model.fit(train_data,y_train)
print("LGBM score: {:.4f} ({:.4f})\n" .format(score.mean(), score.std()))

# %%
Feature_importances = pd.Series(lgb_model.feature_importances_, index = combined_data.columns)
print("lgb model picked " + str(sum(Feature_importances != 0)) + " features and eliminated the other " +  \
      str(sum(Feature_importances == 0)) + " features")
Important_Features = pd.concat([Feature_importances.sort_values().head(10),
                     Feature_importances.sort_values().tail(10)])
Important_Features.plot(kind = "barh")
plt.title("Important Features in the lgb Model")
plt.show()

# %%
# get predictions
predictions = np.exp(lgb_model.predict(test_data))
predictions
# save predictions in Kaggle-friendly format
solutions = pd.DataFrame(data = {'Id':test_ID,'SalePrice':predictions})
solutions.to_csv('lgb_model_predict.csv',index=False)

# %%
# Linear Regression
lr = LinearRegression(fit_intercept=True, normalize=False)
linear_model = lr.fit(combined_data[:ntrain], y_train)

Rsq = linear_model.score(combined_data[:ntrain], y_train)
print("Rsq = " +  str(Rsq))

# %%
linear_model.

# %%
coefs = pd.Series(linear_model.coef_, index = combined_data.columns)
print("Linear selected " + str(sum(coefs != 0)) + " features and eliminated the other " +  \
      str(sum(coefs == 0)) + " features")
imp_coefs = pd.concat([coefs.sort_values().head(10),
                     coefs.sort_values().tail(10)])
imp_coefs.plot(kind = "barh")
plt.title("Coefficients in the linear Model")
plt.show()

# %%
# Plot residuals
plt.scatter(y_train_pred, y_train_pred - train_data, c = "blue", marker = "s", label = "Training data")
plt.scatter(y_test_pred, y_test_pred - test_data, c = "lightgreen", marker = "s", label = "Validation data")
plt.title("Linear regression")
plt.xlabel("Predicted values")
plt.ylabel("Residuals")
plt.legend(loc = "upper left")
plt.hlines(y = 0, xmin = 10.5, xmax = 13.5, color = "red")
plt.show()

# Plot predictions
plt.scatter(y_train_pred, train_data, c = "blue", marker = "s", label = "Training data")
plt.scatter(y_test_pred, test_data, c = "lightgreen", marker = "s", label = "Validation data")
plt.title("Linear regression")
plt.xlabel("Predicted values")
plt.ylabel("Real values")
plt.legend(loc = "upper left")
plt.plot([10.5, 13.5], [10.5, 13.5], c = "red")
plt.show()
